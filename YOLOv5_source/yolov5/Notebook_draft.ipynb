# %% [markdown]
# ## tensorboard

# %%
# !nautilus runs/train
# Out:
# Nautilus-Share-Message: 09:23:01.204: Called "net usershare info" but it failed: 执行子进程“net”失败（No such file or directory）

# %%
# %reload_ext tensorboard

# %%
# %tensorboard --logdir runs/train/exp7
# Out:
#       <iframe id="tensorboard-frame-8ad6e7d9b6840249" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-8ad6e7d9b6840249");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# !nautilus ./runs/detect/

# %%
# !ffplay ~/result/test3.mp4
# Out:
# ffplay version 4.2.4-1ubuntu0.1 Copyright (c) 2003-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
# ...

# %%
# !nautilus ./runs/detect/
# Out:
# Nautilus-Share-Message: 15:56:41.777: Called "net usershare info" but it failed: 执行子进程“net”失败（No such file or directory）

# %%
# !python3 detect.py --weights './runs/train/exp/weights/last.pt' --img 640 --conf 0.25 --device cpu --source './data/video/dam4.mp4'
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='cpu', exist_ok=False, half=False, hide_conf=False, hide_labels=False, imgsz=640, iou_thres=0.45, line_thickness=3, max_det=1000, name='exp', nosave=False, project='runs/detect', save_conf=False, save_crop=False, save_txt=False, source='./data/video/dam4.mp4', update=False, view_img=False, weights=['./runs/train/exp/weights/last.pt'])
# YOLOv5 🚀 2021-6-18 torch 1.9.0+cu102 CPU
#
# Fusing layers...
# /home/yolov5test/.local/lib/python3.8/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Model Summary: 392 layers, 46616721 parameters, 0 gradients, 114.1 GFLOPs
# ...

# %%
sudo gedit /etc/crontab

# %%
# !ffplay ./data/video/dam3.mp4
# Out:
# ffplay version 4.2.4-1ubuntu0.1 Copyright (c) 2003-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
# ...

# %%
# !nautilus 'runs/detect/exp7'
# Out:
# Nautilus-Share-Message: 10:57:14.421: Called "net usershare info" but it failed: 执行子进程“net”失败（No such file or directory）

# %%
# !ffplay 'runs/detect/exp7/dam3.mp4'
# Out:
# ffplay version 4.2.4-1ubuntu0.1 Copyright (c) 2003-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
# ...

# %%
# !gedit

# %%
# !python3 /home/yolov5test/.local/lib/python3.8/site-packages/labelImg/labelImg.py
# Out:
# Image:/home/yolov5test/yolov5/datasets/mask/images/val/test_00001460.jpg -> Annotation:/home/yolov5test/yolov5/datasets/mask/lables/val/test_00001460.xml

# %%
# !ffplay './runs/detect/exp8/mask4.mp4'
# Out:
# ffplay version 4.2.4-1ubuntu0.1 Copyright (c) 2003-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
# ...
