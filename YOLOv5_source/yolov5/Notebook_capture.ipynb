# %%
pip install opencv-python
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 1. opencv调用摄像头截图以及保存

# %% [markdown]
# ### 1.1 功能描述

# %% [markdown]
# 打开和关闭摄像头

# %%
cap = cv2.VideoCapture(0)
cap.release()

# %% [markdown]
# 读取图片

# %% [markdown]
# read():函数返回的ret是一个bool量，成功读取是true，否则返回false
#
# frame:返回的是读取到的图片，以数组的形式贮存

# %%
ret, frame = cap.read()

# %% [markdown]
# 展示图片

# %% [markdown]
# imshow() ：是一个将数组形式的数据转化为图片并展示的函数。它会建立一个窗口，用于展示图片。
#
# destroyAllWindows() ：同样的，使用完成之后我们还需要一个关闭窗口的函数

# %%
cv2.imshow("capture", frame)
cv2.destroyAllWindows()

# %% [markdown]
# 保存图片

# %% [markdown]
# imwrite() ：是一个将数组转化成图片并保存的函数。
#
# 第一个引号内输入的是保存图片的路径以及名称，第二个输入的是需要保存的图片数组数据。该函数支持的图片格式有JPG、JPEG等格式。

# %%
cv2.imwrite(".../fengjunyi/img.jpeg", frame)

# %% [markdown]
# ### 1.2 从rstp逐帧读取

# %%
import cv2
import time
 
def get_img_from_camera_net(folder_path,url):
    cap = cv2.VideoCapture(url)#定义摄像头对象
    # 按帧读取视频，其中ret是bool值（如果读取帧是正确的则返回True，如果文件读到结尾，返回值为False）
    # frame是每一帧的图像，是个三维矩阵，frame颜色空间是ＢＧＲ
    ret, frame = cap.read()
    if ret is True:
        i = 0
        timeF = 25 #每隔25帧提取一次图片，本摄像头每秒内会有25帧，所以要实现每秒截一张图片，则每25帧保存一帧图片
        while True:
            i = i + 1
            if(i % timeF == 0):
                cv2.imwrite(folder_path + str(time.time()) + ".jpg", frame)  # 存储为图像，图像以当前时间命名
            ret, frame = cap.read()
            if ret is False:
                print("断开连接，自主重连")
                cap = cv2.VideoCapture(url)
                ret, frame = cap.read()                
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break
        cap.release()
        cv2.destroyAllWindows()
    else:
        cap = cv2.VideoCapture(url)
        ret, frame = cap.read()
        print("断开连接，自主重连")
 
# 测试
if __name__ == '__main__':
    folder_path = "/home/kevin/yolov5/datasets" #存储图片的本地路径
    url = 'rtsp://admin:012345678m@192.168.0.64:554/h264/ch1/main/av_stream' #网络摄像头的用户名、密码、IP
    get_img_from_camera_net(folder_path , url)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_18520/1870591344.py in <module>
#      32     folder_path = "/home/kevin/yolov5/datasets" #存储图片的本地路径
#      33     url = 'rtsp://admin:012345678m@192.168.0.64:554/h264/ch1/main/av_stream' #网络摄像头的用户名、密码、IP
# ---> 34     get_img_from_camera_net(folder_path , url)
#
# /tmp/ipykernel_18520/1870591344.py in get_img_from_camera_net(folder_path, url)
#      14             if(i % timeF == 0):
#      15                 cv2.imwrite(folder_path + str(time.time()) + ".jpg", frame)  # 存储为图像，图像以当前时间命名
# ---> 16             ret, frame = cap.read()
#      17             if ret is False:
#      18                 print("断开连接，自主重连")
#
# KeyboardInterrupt:

# %% [markdown]
# ### 1.3 从mp4逐帧读取

# %%
# !nautilus ./data/video/output

# %%
# 导入所需要的库
import cv2
import numpy as np
  
# 定义保存图片函数
# image:要保存的图片名字
# addr；图片地址与相片名字的前部分
# num: 相片，名字的后缀。int 类型
def save_image(image,addr,num):
  address = addr + str(num)+ '.jpg'
  cv2.imwrite(address,image)
  
# 读取视频文件
videoCapture = cv2.VideoCapture("./data/video/test4.mp4")
# 通过摄像头的方式
# videoCapture=cv2.VideoCapture(1)
  
#读帧
success, frame = videoCapture.read()
i = 0
timeF = 12
j=0
while success :
  i = i + 1
  if (i % timeF == 0):
    j = j + 1
    save_image(frame,'./data/video/output/test4_',j)
    print('save image:',i)
  success, frame = videoCapture.read()
# Out:
# save image: 12
# save image: 24
# save image: 36
# save image: 48
# save image: 60
# save image: 72
# save image: 84
# save image: 96
# save image: 108
# save image: 120
# save image: 132
# save image: 144
# save image: 156
# save image: 168
# save image: 180
# save image: 192
# save image: 204
# save image: 216
# save image: 228
# save image: 240
# save image: 252
# save image: 264
# save image: 276
# save image: 288
# save image: 300
# save image: 312
# save image: 324
# save image: 336
# save image: 348
# save image: 360
# save image: 372
# save image: 384
# save image: 396
# save image: 408
# save image: 420
# save image: 432
# save image: 444
# save image: 456
# save image: 468
# save image: 480
# save image: 492
# save image: 504
# save image: 516
# save image: 528
# save image: 540
# save image: 552
# save image: 564
# save image: 576
# save image: 588
# save image: 600
# save image: 612
# save image: 624
# save image: 636
# save image: 648
# save image: 660
# save image: 672
# ...

# %% [markdown]
# ## 2. labelImg标记训练集

# %% [markdown]
# ### 2.1 安装环境

# %%
pip install labelImg
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install python-qt5
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f016d1f3490>: Failed to establish a new connection: [Errno -3] 域名解析暂时失败'))': /pypi/simple/python-qt5/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f016d1f34c0>: Failed to establish a new connection: [Errno -3] 域名解析暂时失败'))': /pypi/simple/python-qt5/
# ...

# %%
pip uninstall PyQt5
pip uninstall pyqt5-tools
pip uninstall lxml
# Out:
#   File "/tmp/ipykernel_33534/2645282642.py", line 1
#     pip uninstall PyQt5
#         ^
# SyntaxError: invalid syntax

# %%
# !pip install PyQt5
# !pip install pyqt5-tools
# !pip install lxml
# Out:
# WARNING: Value for scheme.platlib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
# distutils: /usr/local/lib/python3.8/dist-packages
# sysconfig: /usr/lib/python3.8/site-packages
# WARNING: Value for scheme.purelib does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
# distutils: /usr/local/lib/python3.8/dist-packages
# sysconfig: /usr/lib/python3.8/site-packages
# WARNING: Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
# distutils: /usr/local/include/python3.8/UNKNOWN
# sysconfig: /usr/include/python3.8/UNKNOWN
# WARNING: Value for scheme.scripts does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
# distutils: /usr/local/bin
# sysconfig: /usr/bin
# WARNING: Value for scheme.data does not match. Please report this to <https://github.com/pypa/pip/issues/10151>
# distutils: /usr/local
# sysconfig: /usr
# WARNING: Additional context:
# ...

# %%
# !ls /home/yolov5test/.local/lib/python3.8/site-packages
# Out:
# __init__.py  labelImg.py  __pycache__

# %%
# !pyrcc5 -o /home/yolov5test/.local/lib/python3.8/site-packages/libs/resources.py
# Out:
# PyQt5 resource compiler
# Usage: pyrcc5 [options] <inputs>
#
# Options:
#     -o file           Write output to file rather than stdout
#     -threshold level  Threshold to consider compressing files
#     -compress level   Compress input files by level
#     -root path        Prefix resource access path with root path
#     -no-compress      Disable all compression
#     -version          Display version
#     -help             Display this information

# %% [markdown]
# 操作指南：
#
# ```bash
# | Ctrl + s   | 保存                                       |
# +------------+--------------------------------------------+
# | Ctrl + d   | Copy the current label and rect box        |
# +------------+--------------------------------------------+
# | Space      | 标记当前图片已标记        |
# +------------+--------------------------------------------+
# | w          | 创建一个矩形                        |
# +------------+--------------------------------------------+
# | d          | 下一张图片                              |
# +------------+--------------------------------------------+
# | a          | 上一张图片                             |
# +------------+--------------------------------------------+
# | r          | 标记                             |
# ```

# %% [markdown]
# ### 2.2 lableing

# %%
# !nautilus ../datasets
# Out:
# Nautilus-Share-Message: 11:44:27.457: Called "net usershare info" but it failed: 执行子进程“net”失败（No such file or directory）
# ^C

# %%
# !python3 /home/yolov5test/.local/lib/python3.8/site-packages/labelImg/labelImg.py
# Out:
# Image:/home/yolov5test/yolov5/datasets/mask/images/val/test_00003452.jpg -> Annotation:/home/yolov5test/yolov5/yolov5/val/test_00003452.xml
# /home/yolov5test/.local/lib/python3.8/site-packages/labelImg/labelImg.py:948: DeprecationWarning: an integer is required (got type float).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   bar.setValue(bar.value() + bar.singleStep() * units)
# Image:/home/yolov5test/yolov5/datasets/mask/images/val/test_00002435.jpg -> Annotation:/home/yolov5test/yolov5/yolov5/val/test_00002435.xml
# Image:/home/yolov5test/yolov5/datasets/mask/images/val/test_00003030.jpg -> Annotation:/home/yolov5test/yolov5/yolov5/val/test_00003030.xml
# Image:/home/yolov5test/yolov5/datasets/mask/images/val/test_00002130.jpg -> Annotation:/home/yolov5test/yolov5/yolov5/val/test_00002130.xml
# ...

# %% [markdown]
# ### 2.3 转换xml文件为txt lable

# %%
paths = '../datasets/mask/labels'

# %%
# !mkdir ../datasets/mask/labels/tran_train

# %%
import xml.etree.ElementTree as ET
import pickle
import os
from os import listdir, getcwd
from os.path import join
import random
from shutil import copyfile

# 根据自己的数据标签修改
classes=["face","mask","face_mask"]


def clear_hidden_files(path):
    dir_list = os.listdir(path)
    for i in dir_list:
        abspath = os.path.join(os.path.abspath(path), i)
        if os.path.isfile(abspath):
            if i.startswith("._"):
                os.remove(abspath)
        else:
            clear_hidden_files(abspath)

def convert(size, box):
    dw = 1./size[0]
    dh = 1./size[1]
    x = (box[0] + box[1])/2.0
    y = (box[2] + box[3])/2.0
    w = box[1] - box[0]
    h = box[3] - box[2]
    x = x*dw
    w = w*dw
    y = y*dh
    h = h*dh
    return (x,y,w,h)

def convert_annotation(image_id):
    in_file = open(paths + '/train/%s.xml' %image_id)
    out_file = open(paths + '/tran_train/%s.txt' %image_id, 'w')
    tree=ET.parse(in_file)
    root = tree.getroot()
    size = root.find('size')
    w = int(size.find('width').text)
    h = int(size.find('height').text)

    for obj in root.iter('object'):
        difficult = obj.find('difficult').text
        cls = obj.find('name').text
        if cls not in classes or int(difficult) == 1:
            continue
        cls_id = classes.index(cls)
        xmlbox = obj.find('bndbox')
        b = (float(xmlbox.find('xmin').text), float(xmlbox.find('xmax').text), float(xmlbox.find('ymin').text), float(xmlbox.find('ymax').text))
        bb = convert((w,h), b)
        out_file.write(str(cls_id) + " " + " ".join([str(a) for a in bb]) + '\n')
    in_file.close()
    out_file.close()

# %% [markdown]
# ### 2.4 清洗异常数据

# %%
for file in os.listdir(paths + "/train"):
    file = file[:-4]
    try:
        convert_annotation(file)        
    except Exception as e:
        print(file,e)
        # !rm '../datasets/mask/images/train/'$file'.jpg'
        print(file + " img已被删除")
        # !rm '../datasets/mask/labels/train/'$file'.xml'
        print(file + " xml已被删除")
        # !rm '../datasets/mask/labels/tran_train/'$file'.txt'
        print(file + " txt已被删除")
    continue
# Out:
# test_00002804 float division by zero
# test_00002804 img已被删除
# test_00002804 xml已被删除
# test_00002804 txt已被删除
# test_00003910 float division by zero
# test_00003910 img已被删除
# test_00003910 xml已被删除
# test_00003910 txt已被删除
# test_00001881 float division by zero
# test_00001881 img已被删除
# test_00001881 xml已被删除
# test_00001881 txt已被删除
# test_00002371 float division by zero
# test_00002371 img已被删除
# test_00002371 xml已被删除
# test_00002371 txt已被删除
# test_00001120 float division by zero
# test_00001120 img已被删除
# test_00001120 xml已被删除
# test_00001120 txt已被删除
# test_00003484 float division by zero
# test_00003484 img已被删除
# test_00003484 xml已被删除
# test_00003484 txt已被删除
# test_00000029 float division by zero
# test_00000029 img已被删除
# test_00000029 xml已被删除
# test_00000029 txt已被删除
# test_00003096 float division by zero
# test_00003096 img已被删除
# test_00003096 xml已被删除
# test_00003096 txt已被删除
# test_00003986 float division by zero
# test_00003986 img已被删除
# test_00003986 xml已被删除
# test_00003986 txt已被删除
# ...

# %%
# !mkdir ../datasets/mask/labels/tran_val

# %%
import xml.etree.ElementTree as ET
import pickle
import os
from os import listdir, getcwd
from os.path import join
import random
from shutil import copyfile

# 根据自己的数据标签修改
classes=["face","mask","face_mask"]


def clear_hidden_files(path):
    dir_list = os.listdir(path)
    for i in dir_list:
        abspath = os.path.join(os.path.abspath(path), i)
        if os.path.isfile(abspath):
            if i.startswith("._"):
                os.remove(abspath)
        else:
            clear_hidden_files(abspath)

def convert(size, box):
    dw = 1./size[0]
    dh = 1./size[1]
    x = (box[0] + box[1])/2.0
    y = (box[2] + box[3])/2.0
    w = box[1] - box[0]
    h = box[3] - box[2]
    x = x*dw
    w = w*dw
    y = y*dh
    h = h*dh
    return (x,y,w,h)

def convert_annotation(image_id):
    in_file = open(paths + '/val/%s.xml' %image_id)
    out_file = open(paths + '/tran_val/%s.txt' %image_id, 'w')
    tree=ET.parse(in_file)
    root = tree.getroot()
    size = root.find('size')
    w = int(size.find('width').text)
    h = int(size.find('height').text)

    for obj in root.iter('object'):
        difficult = obj.find('difficult').text
        cls = obj.find('name').text
        if cls not in classes or int(difficult) == 1:
            continue
        cls_id = classes.index(cls)
        xmlbox = obj.find('bndbox')
        b = (float(xmlbox.find('xmin').text), float(xmlbox.find('xmax').text), float(xmlbox.find('ymin').text), float(xmlbox.find('ymax').text))
        bb = convert((w,h), b)
        out_file.write(str(cls_id) + " " + " ".join([str(a) for a in bb]) + '\n')
    in_file.close()
    out_file.close()

# %%
for file in os.listdir(paths + "/val"):
    file = file[:-4]
    try:
        convert_annotation(file)        
    except Exception as e:
        print(file,e)
        # !rm '../datasets/mask/images/val/'$file'.jpg'
        print(file + " img已被删除")
        # !rm '../datasets/mask/labels/val/'$file'.xml'
        print(file + " xml已被删除")
        # !rm '../datasets/mask/labels/tran_val/'$file'.txt'
        print(file + " txt已被删除")
    continue
# Out:
# test_00003452 'NoneType' object has no attribute 'find'
# test_00003452 img已被删除
# test_00003452 xml已被删除
# test_00003452 txt已被删除
# test_00002435 float division by zero
# test_00002435 img已被删除
# test_00002435 xml已被删除
# test_00002435 txt已被删除
# test_00003030 float division by zero
# test_00003030 img已被删除
# test_00003030 xml已被删除
# test_00003030 txt已被删除
# test_00002130 float division by zero
# test_00002130 img已被删除
# test_00002130 xml已被删除
# test_00002130 txt已被删除
# test_00001460 float division by zero
# test_00001460 img已被删除
# test_00001460 xml已被删除
# test_00001460 txt已被删除
# test_00003435 'NoneType' object has no attribute 'find'
# test_00003435 img已被删除
# test_00003435 xml已被删除
# test_00003435 txt已被删除
# test_00003489 float division by zero
# test_00003489 img已被删除
# test_00003489 xml已被删除
# test_00003489 txt已被删除
# test_00003436 'NoneType' object has no attribute 'find'
# test_00003436 img已被删除
# test_00003436 xml已被删除
# test_00003436 txt已被删除
# test_00001029 float division by zero
# ...

# %% [markdown]
# ### 2.5 检查文件

# %%
# !nautilus ../datasets/mask/labels
# Out:
# Nautilus-Share-Message: 14:09:19.306: Called "net usershare info" but it failed: 执行子进程“net”失败（No such file or directory）

# %% [markdown]
# ### 2.6 批量更改标签

# %%
import os, glob

if __name__ == '__main__':
    for file in os.listdir("../VisDrone/VisDrone2019-DET-test-dev/labels/"):
        txt_list = glob.glob("../VisDrone/VisDrone2019-DET-test-dev/labels/"+file)
        for txt_item in txt_list:
            with open(txt_item) as f:
                lines = f.readlines()
            with open(txt_item, 'w') as f:
                for line in lines:
                    line_split = line.strip().split()
                    if line_split[0] == '2':
                        line_split[0] = '0'
                    elif line_split[0] == '3':
                        line_split[0] = '1'
                    elif line_split[0] == '4':
                        line_split[0] = '2'
                    elif line_split[0] == '5':
                        line_split[0] = '3'
                    elif line_split[0] == '8':
                        line_split[0] = '4'
                    elif line_split[0] == '9':
                        line_split[0] = '5'
                    f.write(
                        line_split[0] + ' ' +
                        line_split[1] + ' ' +
                        line_split[2] + ' ' +
                        line_split[3] + ' ' +
                        line_split[4]+'\n')
            pass

# %%
import os, glob

line_splites = []

if __name__ == '__main__':
    for file in os.listdir("../VisDrone/VisDrone2019-DET-train/labels/"):
        txt_list = glob.glob("../VisDrone/VisDrone2019-DET-train/labels/"+file)
        for txt_item in txt_list:
            with open(txt_item) as f:
                lines = f.readlines()
            with open(txt_item, 'w') as f:
                for line in lines:
                    line_split = line.strip().split()
                    line_splites.append(line_split[0])
                    f.write(
                        line_split[0] + ' ' +
                        line_split[1] + ' ' +
                        line_split[2] + ' ' +
                        line_split[3] + ' ' +
                        line_split[4]+'\n')
            pass

list(set(line_splites))
# Out:
# ['5', '2', '3', '0', '4', '1']

# %% [markdown]
# ## 3. 可视化

# %% [markdown]
# ### 3.1 查看类别数量

# %%
import os, glob

if __name__ == '__main__':
    n_face = 0
    n_mask = 0
    n_face_mask = 0
    for file in os.listdir("../datasets/mask/labels/tran_train/"):
        txt_list = glob.glob("../datasets/mask/labels/tran_train/"+file)
        for txt_item in txt_list:
            with open(txt_item) as f:
                lines = f.readlines()
            with open(txt_item, 'w') as f:
                for line in lines:
                    line_split = line.strip().split()
                    if line_split[0] == '0':
                        n_face += 1
                    elif line_split[0] == '1':
                        n_mask += 1
                    elif line_split[0] == '2':
                        n_face_mask += 1
                    f.write(
                        line_split[0] + ' ' +
                        line_split[1] + ' ' +
                        line_split[2] + ' ' +
                        line_split[3] + ' ' +
                        line_split[4]+'\n')
            pass
    print(n_face)
    print(n_mask)
    print(n_face_mask)
# Out:
# 10590
# 2822
# 2890
